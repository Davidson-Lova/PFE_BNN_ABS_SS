# %%
import numpy as np
import pylab as plt

# %%
np.random.normal(loc = 1, scale = 11)
# Out:
# 1.4609275580899153

# %% [markdown]
# <img src="photo/FNN_1.png" />

# %%
size_of_theta = 7
theta = [np.random.normal() for _ in range(size_of_theta)]

'''
theta = w_1(2) | w_2(2)| b_1(2)| b_2(1) 
'''

# %%
theta
# Out:
# [-0.29506949870072685,
#  0.5222065405871277,
#  0.947989692376732,
#  0.8596232815940217,
#  0.14409486991264134,
#  0.17962981356577992,
#  -2.773098983165593]

# %%
theta[-1]
# Out:
# -2.773098983165593

# %%
def simuler_theta(theta, sigma) :

# %%
def FNN(x, theta):
    return np.tanh(theta[6] + ( theta[2]*np.tanh(theta[4] + x*theta[0]) + theta[3]*np.tanh(theta[5] + x*theta[1]) ))

# %%
FNN(1, theta)
# Out:
# -0.9834995213257813
